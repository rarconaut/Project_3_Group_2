# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from config import my_password

# %%
train_df = pd.read_csv('aug_train.csv')

# %%
train_df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0

# %%
train_df.drop(['city_development_index', 'last_new_job', 'training_hours'], axis = 'columns', inplace = True)
train_df.head()
# Out:
#    enrollee_id      city gender      relevent_experience enrolled_university  \
# 0         8949  city_103   Male  Has relevent experience       no_enrollment
# 1        29725   city_40   Male   No relevent experience       no_enrollment
# 2        11561   city_21    NaN   No relevent experience    Full time course
# 3        33241  city_115    NaN   No relevent experience                 NaN
# 4          666  city_162   Male  Has relevent experience       no_enrollment
#
#   education_level major_discipline experience company_size    company_type  \
# 0        Graduate             STEM        >20          NaN             NaN
# 1        Graduate             STEM         15        50-99         Pvt Ltd
# 2        Graduate             STEM          5          NaN             NaN
# 3        Graduate  Business Degree         <1          NaN         Pvt Ltd
# 4         Masters             STEM        >20        50-99  Funded Startup
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          19158 non-null  int64
#  1   city                 19158 non-null  object
#  2   gender               14650 non-null  object
#  3   relevent_experience  19158 non-null  object
#  4   enrolled_university  18772 non-null  object
#  5   education_level      18698 non-null  object
#  6   major_discipline     16345 non-null  object
#  7   experience           19093 non-null  object
#  8   company_size         13220 non-null  object
#  9   company_type         13018 non-null  object
#  10  target               19158 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.6+ MB

# %%
train_df.dropna(how='any', inplace=True)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8977 entries, 1 to 19155
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          8977 non-null   int64
#  1   city                 8977 non-null   object
#  2   gender               8977 non-null   object
#  3   relevent_experience  8977 non-null   object
#  4   enrolled_university  8977 non-null   object
#  5   education_level      8977 non-null   object
#  6   major_discipline     8977 non-null   object
#  7   experience           8977 non-null   object
#  8   company_size         8977 non-null   object
#  9   company_type         8977 non-null   object
#  10  target               8977 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 841.6+ KB

# %%
train_df.to_csv('train_cleaned.csv', index=False)

# %%
male_filter = train_df['gender'] == 'Male'
train_male_df = train_df[male_filter]
train_male_df.head()
# Out:
#     enrollee_id      city gender      relevent_experience enrolled_university  \
# 1         29725   city_40   Male   No relevent experience       no_enrollment
# 4           666  city_162   Male  Has relevent experience       no_enrollment
# 7           402   city_46   Male  Has relevent experience       no_enrollment
# 8         27107  city_103   Male  Has relevent experience       no_enrollment
# 11        23853  city_103   Male  Has relevent experience       no_enrollment
#
#    education_level major_discipline experience company_size    company_type  \
# 1         Graduate             STEM         15        50-99         Pvt Ltd
# 4          Masters             STEM        >20        50-99  Funded Startup
# 7         Graduate             STEM         13          <10         Pvt Ltd
# 8         Graduate             STEM          7        50-99         Pvt Ltd
# 11        Graduate             STEM          5    5000-9999         Pvt Ltd
#
#     target
# 1      0.0
# 4      0.0
# 7      1.0
# 8      1.0
# 11     0.0

# %%
female_filter = train_df['gender'] == 'Female'
train_female_df = train_df[female_filter]
train_female_df.head()
# Out:
#     enrollee_id      city  gender      relevent_experience  \
# 33        26966  city_160  Female  Has relevent experience
# 40         2547  city_114  Female  Has relevent experience
# 68        12730   city_16  Female  Has relevent experience
# 79        31449  city_103  Female  Has relevent experience
# 86        30937   city_57  Female   No relevent experience
#
#    enrolled_university education_level major_discipline experience  \
# 33       no_enrollment        Graduate             STEM        >20
# 40    Full time course         Masters             STEM         16
# 68       no_enrollment         Masters       Humanities         14
# 79       no_enrollment         Masters             STEM          2
# 86    Part time course        Graduate             STEM         <1
#
#    company_size         company_type  target
# 33      100-500              Pvt Ltd     0.0
# 40    1000-4999        Public Sector     0.0
# 68      500-999        Public Sector     0.0
# 79          <10  Early Stage Startup     0.0
# 86        10/49              Pvt Ltd     0.0

# %%
train_male_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8094 entries, 1 to 19155
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          8094 non-null   int64
#  1   city                 8094 non-null   object
#  2   gender               8094 non-null   object
#  3   relevent_experience  8094 non-null   object
#  4   enrolled_university  8094 non-null   object
#  5   education_level      8094 non-null   object
#  6   major_discipline     8094 non-null   object
#  7   experience           8094 non-null   object
#  8   company_size         8094 non-null   object
#  9   company_type         8094 non-null   object
#  10  target               8094 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 758.8+ KB

# %%
train_female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 805 entries, 33 to 19152
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          805 non-null    int64
#  1   city                 805 non-null    object
#  2   gender               805 non-null    object
#  3   relevent_experience  805 non-null    object
#  4   enrolled_university  805 non-null    object
#  5   education_level      805 non-null    object
#  6   major_discipline     805 non-null    object
#  7   experience           805 non-null    object
#  8   company_size         805 non-null    object
#  9   company_type         805 non-null    object
#  10  target               805 non-null    float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 75.5+ KB

# %%
male_sample_df = train_male_df.sample(n=805)
male_sample_df.head()
# Out:
#        enrollee_id      city gender      relevent_experience  \
# 12746         1321  city_103   Male  Has relevent experience
# 15856         6792   city_57   Male  Has relevent experience
# 12131        32813  city_173   Male   No relevent experience
# 829           9147   city_16   Male  Has relevent experience
# 7206         11930  city_102   Male  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 12746       no_enrollment        Graduate             STEM          5
# 15856       no_enrollment         Masters             STEM         12
# 12131    Full time course        Graduate       Humanities          2
# 829         no_enrollment        Graduate             STEM         11
# 7206        no_enrollment        Graduate             STEM        >20
#
#       company_size company_type  target
# 12746       10000+      Pvt Ltd     0.0
# 15856        50-99      Pvt Ltd     0.0
# 12131    1000-4999      Pvt Ltd     0.0
# 829        100-500      Pvt Ltd     0.0
# 7206         50-99      Pvt Ltd     0.0

# %%
merged_df = pd.concat([male_sample_df, train_female_df], axis=0)
merged_df.head()
# Out:
#        enrollee_id      city gender      relevent_experience  \
# 12746         1321  city_103   Male  Has relevent experience
# 15856         6792   city_57   Male  Has relevent experience
# 12131        32813  city_173   Male   No relevent experience
# 829           9147   city_16   Male  Has relevent experience
# 7206         11930  city_102   Male  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 12746       no_enrollment        Graduate             STEM          5
# 15856       no_enrollment         Masters             STEM         12
# 12131    Full time course        Graduate       Humanities          2
# 829         no_enrollment        Graduate             STEM         11
# 7206        no_enrollment        Graduate             STEM        >20
#
#       company_size company_type  target
# 12746       10000+      Pvt Ltd     0.0
# 15856        50-99      Pvt Ltd     0.0
# 12131    1000-4999      Pvt Ltd     0.0
# 829        100-500      Pvt Ltd     0.0
# 7206         50-99      Pvt Ltd     0.0

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1610 entries, 12746 to 19152
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          1610 non-null   int64
#  1   city                 1610 non-null   object
#  2   gender               1610 non-null   object
#  3   relevent_experience  1610 non-null   object
#  4   enrolled_university  1610 non-null   object
#  5   education_level      1610 non-null   object
#  6   major_discipline     1610 non-null   object
#  7   experience           1610 non-null   object
#  8   company_size         1610 non-null   object
#  9   company_type         1610 non-null   object
#  10  target               1610 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 150.9+ KB

# %%
merged_df.to_csv('train_balanced.csv', index=False)

# %% [markdown]
# ## Connect to Postgres Database

# %%
rds_connection_string = "postgres:password@localhost:5432/job_change"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['alembic_version', 'response', 'train_balanced', 'test_balanced']

# %% [markdown]
# ## Export DataFrame to SQL

# %%
merged_df.to_sql(name='train_balanced', con=engine, if_exists='replace', index=False)
