# %%
import pandas as pd
import os
from sqlalchemy import create_engine
# from config import my_password

# %%
test_df = pd.read_csv('aug_test.csv')

# %%
test_df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
test_df.drop(['city_development_index', 'last_new_job', 'training_hours'], axis = 'columns', inplace = True)
test_df.head()
# Out:
#    enrollee_id      city  gender      relevent_experience enrolled_university  \
# 0        32403   city_41    Male  Has relevent experience    Full time course
# 1         9858  city_103  Female  Has relevent experience       no_enrollment
# 2        31806   city_21    Male   No relevent experience       no_enrollment
# 3        27385   city_13    Male  Has relevent experience       no_enrollment
# 4        27724  city_103    Male  Has relevent experience       no_enrollment
#
#   education_level major_discipline experience company_size company_type
# 0        Graduate             STEM          9          <10          NaN
# 1        Graduate             STEM          5          NaN      Pvt Ltd
# 2     High School              NaN         <1          NaN      Pvt Ltd
# 3         Masters             STEM         11        10/49      Pvt Ltd
# 4        Graduate             STEM        >20       10000+      Pvt Ltd

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          2129 non-null   int64
#  1   city                 2129 non-null   object
#  2   gender               1621 non-null   object
#  3   relevent_experience  2129 non-null   object
#  4   enrolled_university  2098 non-null   object
#  5   education_level      2077 non-null   object
#  6   major_discipline     1817 non-null   object
#  7   experience           2124 non-null   object
#  8   company_size         1507 non-null   object
#  9   company_type         1495 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 166.5+ KB

# %%
test_df.dropna(how='any', inplace=True)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1020 entries, 3 to 2128
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          1020 non-null   int64
#  1   city                 1020 non-null   object
#  2   gender               1020 non-null   object
#  3   relevent_experience  1020 non-null   object
#  4   enrolled_university  1020 non-null   object
#  5   education_level      1020 non-null   object
#  6   major_discipline     1020 non-null   object
#  7   experience           1020 non-null   object
#  8   company_size         1020 non-null   object
#  9   company_type         1020 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 87.7+ KB

# %%
test_df.to_csv('../Kaggle Data/test_cleaned.csv', index=False)

# %%
male_filter = test_df['gender'] == 'Male'
test_male_df = test_df[male_filter]
test_male_df.head()
# Out:
#     enrollee_id      city gender      relevent_experience enrolled_university  \
# 3         27385   city_13   Male  Has relevent experience       no_enrollment
# 4         27724  city_103   Male  Has relevent experience       no_enrollment
# 11         9272   city_90   Male  Has relevent experience       no_enrollment
# 12        14249   city_46   Male  Has relevent experience       no_enrollment
# 16         7865   city_21   Male  Has relevent experience       no_enrollment
#
#    education_level major_discipline experience company_size company_type
# 3          Masters             STEM         11        10/49      Pvt Ltd
# 4         Graduate             STEM        >20       10000+      Pvt Ltd
# 11        Graduate             STEM         20        10/49      Pvt Ltd
# 12        Graduate             STEM          8      100-500        Other
# 16         Masters             STEM          4      100-500      Pvt Ltd

# %%
female_filter = test_df['gender'] == 'Female'
test_female_df = test_df[female_filter]
test_female_df.head()
# Out:
#      enrollee_id      city  gender      relevent_experience  \
# 41         25855  city_103  Female  Has relevent experience
# 64          2094   city_64  Female  Has relevent experience
# 128        21920   city_16  Female   No relevent experience
# 134        14566   city_69  Female  Has relevent experience
# 163        10021   city_16  Female  Has relevent experience
#
#     enrolled_university education_level major_discipline experience  \
# 41        no_enrollment        Graduate             Arts          4
# 64        no_enrollment        Graduate             STEM         18
# 128       no_enrollment             Phd             STEM         19
# 134    Part time course        Graduate             STEM          7
# 163       no_enrollment        Graduate             STEM          5
#
#     company_size company_type
# 41         50-99      Pvt Ltd
# 64       100-500      Pvt Ltd
# 128    1000-4999          NGO
# 134      500-999      Pvt Ltd
# 163       10000+      Pvt Ltd

# %%
test_male_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 3 to 2128
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          925 non-null    int64
#  1   city                 925 non-null    object
#  2   gender               925 non-null    object
#  3   relevent_experience  925 non-null    object
#  4   enrolled_university  925 non-null    object
#  5   education_level      925 non-null    object
#  6   major_discipline     925 non-null    object
#  7   experience           925 non-null    object
#  8   company_size         925 non-null    object
#  9   company_type         925 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 79.5+ KB

# %%
test_female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 41 to 2052
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          85 non-null     int64
#  1   city                 85 non-null     object
#  2   gender               85 non-null     object
#  3   relevent_experience  85 non-null     object
#  4   enrolled_university  85 non-null     object
#  5   education_level      85 non-null     object
#  6   major_discipline     85 non-null     object
#  7   experience           85 non-null     object
#  8   company_size         85 non-null     object
#  9   company_type         85 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 7.3+ KB

# %%
male_sample_df = test_male_df.sample(n=85)
male_sample_df.head()
# Out:
#       enrollee_id      city gender      relevent_experience  \
# 104         20453   city_27   Male  Has relevent experience
# 1673        10663  city_114   Male  Has relevent experience
# 233         15380   city_21   Male  Has relevent experience
# 316         30759   city_74   Male   No relevent experience
# 2081        21057  city_103   Male  Has relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 104        no_enrollment        Graduate             STEM          3
# 1673       no_enrollment         Masters             STEM         11
# 233        no_enrollment        Graduate             STEM          5
# 316        no_enrollment        Graduate            Other          2
# 2081       no_enrollment         Masters             STEM          9
#
#      company_size company_type
# 104         50-99      Pvt Ltd
# 1673    1000-4999      Pvt Ltd
# 233       500-999      Pvt Ltd
# 316         10/49          NGO
# ...

# %%
merged_df = pd.concat([male_sample_df, test_female_df], axis=0)
merged_df.head()
# Out:
#       enrollee_id      city gender      relevent_experience  \
# 104         20453   city_27   Male  Has relevent experience
# 1673        10663  city_114   Male  Has relevent experience
# 233         15380   city_21   Male  Has relevent experience
# 316         30759   city_74   Male   No relevent experience
# 2081        21057  city_103   Male  Has relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 104        no_enrollment        Graduate             STEM          3
# 1673       no_enrollment         Masters             STEM         11
# 233        no_enrollment        Graduate             STEM          5
# 316        no_enrollment        Graduate            Other          2
# 2081       no_enrollment         Masters             STEM          9
#
#      company_size company_type
# 104         50-99      Pvt Ltd
# 1673    1000-4999      Pvt Ltd
# 233       500-999      Pvt Ltd
# 316         10/49          NGO
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 104 to 2052
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   enrollee_id          170 non-null    int64
#  1   city                 170 non-null    object
#  2   gender               170 non-null    object
#  3   relevent_experience  170 non-null    object
#  4   enrolled_university  170 non-null    object
#  5   education_level      170 non-null    object
#  6   major_discipline     170 non-null    object
#  7   experience           170 non-null    object
#  8   company_size         170 non-null    object
#  9   company_type         170 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 14.6+ KB

# %%
merged_df.to_csv('../Kaggle Data/test_balanced.csv', index=False)

# %% [markdown]
# ## Connect to Postgres Database

# %%
# rds_connection_string = "postgres:my_password@localhost:5432/ml_jobchanging"
# engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# engine.table_names()
# Out:
# ['balanced']

# %% [markdown]
# ## Export DataFrame to SQL

# %%
# merged_df.to_sql(name='test_balanced', con=engine, if_exists='replace', index=False)
